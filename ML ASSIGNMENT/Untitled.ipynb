# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
iris = load_iris()
X = iris.data
Y = iris.target
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=39)

# %%
logreg = LogisticRegression(max_iter=150)
logreg.fit(X_train, Y_train)
# Out:
# LogisticRegression(max_iter=150)

# %%
Y_pred = logreg.predict(X_test)
print(Y_pred,"****",Y_test)
# Out:
# [0 0 2 1 0 0 2 0 2 2 1 0 2 1 1 1 2 2 2 0 2 0 0 1 1 0 1 1 2 1] **** [0 0 2 1 0 0 2 0 2 2 1 0 2 1 1 1 2 2 2 0 2 0 0 1 1 0 2 1 2 1]

# %%
accuracy = accuracy_score(Y_pred,Y_test)
print("The accuracy of model is: ",accuracy*100,"%")
# Out:
# The accuracy of model is:  96.66666666666667 %

# %%
random_data =[5.1, 3.5, 1.4, 0.2]
print(iris.target_names[logreg.predict([random_data])[0]])
# Out:
# setosa

# %%
random_data =[5.5, 4.0, 1.5, 0.6]
print(iris.target_names[logreg.predict([random_data])[0]])
# Out:
# setosa

# %%
X_test_df = pd.DataFrame(X_test, columns=iris.feature_names)

# Select two features to plot (Petal length & Petal width)
feature_x = "petal length (cm)"
feature_y = "petal width (cm)"

# Actual values plot
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
sns.scatterplot(x=X_test_df[feature_x], y=X_test_df[feature_y], hue=Y_test, palette="bright", edgecolor="k")
plt.title("Actual Classes")
plt.xlabel(feature_x)
plt.ylabel(feature_y)

# Predicted values plot
plt.subplot(1, 2, 2)
sns.scatterplot(x=X_test_df[feature_x], y=X_test_df[feature_y], hue=Y_pred, palette="bright", edgecolor="k", marker="X")
plt.title("Predicted Classes")
plt.xlabel(feature_x)
plt.ylabel(feature_y)

plt.tight_layout()
plt.show()
